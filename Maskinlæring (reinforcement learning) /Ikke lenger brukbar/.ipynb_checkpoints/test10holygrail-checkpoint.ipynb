# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# === Load dataset ===
df = pd.read_csv('/Users/biraveennedunchelian/Documents/Masteroppgave/Masteroppgave/Newest addition/sinusoid curve/sinusoidal_log1idk.csv')  # Replace with your dataset path
data = df['Y'].values  # Assuming 'Y' is the target variable

# === TimeSeriesSplit (for K-Fold) ===
tss = TimeSeriesSplit(n_splits=5)  # Define 5 splits for K-fold cross-validation

# === Cross-validation loop ===
fold = 0
preds = []
scores = []

for train_idx, val_idx in tss.split(data):
    train = data[train_idx]
    test = data[val_idx]

    # Prepare features (lagged values as features)
    X_train = np.array([train[i-1:i] for i in range(1, len(train))])
    y_train = train[1:]
    
    X_test = np.array([test[i-1:i] for i in range(1, len(test))])
    y_test = test[1:]

    # === XGBoost model setup ===
    reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                           n_estimators=1000,
                           objective='reg:squarederror',
                           max_depth=3,
                           learning_rate=0.01)
    
    # Fit the model
    reg.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            verbose=100)
    
    # Predict and calculate RMSE
    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    scores.append(score)

    fold += 1
    print(f"Fold {fold} | RMSE: {score:.4f}")

# === Plot predictions ===
plt.figure(figsize=(15, 5))
plt.plot(data, label='Actual data')
plt.plot(np.concatenate(preds), label='Predictions (XGBoost)', linestyle='--')
plt.title("XGBoost Time Series Forecasting with K-Fold Cross Validation")
plt.xlabel("Time Steps")
plt.ylabel("CPU Usage (%)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# === Results ===
print(f"Average RMSE over all folds: {np.mean(scores):.4f}")
# Out:
# [0]	validation_0-rmse:56.44274	validation_1-rmse:56.49134
# [100]	validation_0-rmse:21.09964	validation_1-rmse:21.15476
# [200]	validation_0-rmse:8.55267	validation_1-rmse:8.65045
# [300]	validation_0-rmse:4.74839	validation_1-rmse:4.89158
# [400]	validation_0-rmse:3.95150	validation_1-rmse:4.11815
# [500]	validation_0-rmse:3.82026	validation_1-rmse:4.00253
# [600]	validation_0-rmse:3.79369	validation_1-rmse:3.98982
# [700]	validation_0-rmse:3.78222	validation_1-rmse:3.98962
# [800]	validation_0-rmse:3.77575	validation_1-rmse:3.99282
# [900]	validation_0-rmse:3.77160	validation_1-rmse:3.99551
# [999]	validation_0-rmse:3.76605	validation_1-rmse:3.99851
# Fold 1 | RMSE: 3.9985
# [0]	validation_0-rmse:56.46444	validation_1-rmse:56.46400
# [100]	validation_0-rmse:21.07454	validation_1-rmse:21.06183
# [200]	validation_0-rmse:8.54806	validation_1-rmse:8.52796
# [300]	validation_0-rmse:4.77516	validation_1-rmse:4.75822
# [400]	validation_0-rmse:3.99625	validation_1-rmse:3.98430
# [500]	validation_0-rmse:3.87621	validation_1-rmse:3.86697
# [600]	validation_0-rmse:3.85580	validation_1-rmse:3.84689
# [700]	validation_0-rmse:3.84986	validation_1-rmse:3.84130
# [800]	validation_0-rmse:3.84655	validation_1-rmse:3.83824
# [900]	validation_0-rmse:3.84444	validation_1-rmse:3.83639
# [999]	validation_0-rmse:3.84219	validation_1-rmse:3.83398
# Fold 2 | RMSE: 3.8340
# [0]	validation_0-rmse:56.46191	validation_1-rmse:56.49310
# [100]	validation_0-rmse:21.05828	validation_1-rmse:21.09129
# [200]	validation_0-rmse:8.53585	validation_1-rmse:8.58129
# [300]	validation_0-rmse:4.76792	validation_1-rmse:4.82143
# [400]	validation_0-rmse:3.99140	validation_1-rmse:4.04600
# [500]	validation_0-rmse:3.87055	validation_1-rmse:3.92758
# [600]	validation_0-rmse:3.84936	validation_1-rmse:3.90968
# [700]	validation_0-rmse:3.84256	validation_1-rmse:3.90574
# [800]	validation_0-rmse:3.83833	validation_1-rmse:3.90432
# [900]	validation_0-rmse:3.83503	validation_1-rmse:3.90396
# [999]	validation_0-rmse:3.83242	validation_1-rmse:3.90282
# Fold 3 | RMSE: 3.9028
# [0]	validation_0-rmse:56.46834	validation_1-rmse:56.45689
# [100]	validation_0-rmse:21.05492	validation_1-rmse:21.03812
# [200]	validation_0-rmse:8.53482	validation_1-rmse:8.51329
# [300]	validation_0-rmse:4.77100	validation_1-rmse:4.75532
# [400]	validation_0-rmse:3.99667	validation_1-rmse:3.98750
# [500]	validation_0-rmse:3.87752	validation_1-rmse:3.87128
# [600]	validation_0-rmse:3.85758	validation_1-rmse:3.85224
# [700]	validation_0-rmse:3.85129	validation_1-rmse:3.84626
# [800]	validation_0-rmse:3.84796	validation_1-rmse:3.84331
# [900]	validation_0-rmse:3.84577	validation_1-rmse:3.84148
# [999]	validation_0-rmse:3.84333	validation_1-rmse:3.83889
# Fold 4 | RMSE: 3.8389
# [0]	validation_0-rmse:56.46525	validation_1-rmse:56.49533
# [100]	validation_0-rmse:21.04879	validation_1-rmse:21.08095
# [200]	validation_0-rmse:8.53038	validation_1-rmse:8.57032
# [300]	validation_0-rmse:4.76786	validation_1-rmse:4.80794
# [400]	validation_0-rmse:3.99398	validation_1-rmse:4.03100
# [500]	validation_0-rmse:3.87464	validation_1-rmse:3.91102
# [600]	validation_0-rmse:3.85405	validation_1-rmse:3.89123
# [700]	validation_0-rmse:3.84752	validation_1-rmse:3.88636
# [800]	validation_0-rmse:3.84445	validation_1-rmse:3.88386
# [900]	validation_0-rmse:3.84207	validation_1-rmse:3.88208
# [999]	validation_0-rmse:3.83966	validation_1-rmse:3.88029
# Fold 5 | RMSE: 3.8803
# Average RMSE over all folds: 3.8909

# %%
# === Generate future predictions ===
n_future_steps = 1000  # Forecast the next 1000 steps
predicted_future = []

# Use the last data point to start the forecasting
last_value = data[-1]

for _ in range(n_future_steps):
    # Prepare the input for prediction (last_value as the feature)
    X_future = np.array([[last_value]])  # Use the last value as the feature
    y_future = model.predict(X_future)
    
    # Append prediction to results and update the last_value for the next prediction
    predicted_future.append(y_future[0])
    last_value = y_future[0]  # Update last_value for the next step

# === Plot actual data and future forecast ===
plt.figure(figsize=(15, 6))

# Plot the actual data
plt.plot(data, label='Actual Data')

# Plot the future predictions
future_x = range(len(data), len(data) + n_future_steps)
plt.plot(future_x, predicted_future, label='Future Forecast', linestyle='--')

plt.title('XGBoost Time Series Forecasting - Future Predictions')
plt.xlabel('Time Steps')
plt.ylabel('CPU Usage')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [0]	validation_0-rmse:56.46916
# [100]	validation_0-rmse:21.01755
# [200]	validation_0-rmse:8.50323
# [300]	validation_0-rmse:4.74927
# [400]	validation_0-rmse:3.97352
# [500]	validation_0-rmse:3.85224
# [600]	validation_0-rmse:3.83125
# [700]	validation_0-rmse:3.82492
# [800]	validation_0-rmse:3.82172
# [900]	validation_0-rmse:3.81951
# [1000]	validation_0-rmse:3.81845
# [1100]	validation_0-rmse:3.81731
# [1200]	validation_0-rmse:3.81599
# [1300]	validation_0-rmse:3.81485
# [1400]	validation_0-rmse:3.81405
# [1500]	validation_0-rmse:3.81328
# [1600]	validation_0-rmse:3.81271
# [1700]	validation_0-rmse:3.81229
# [1800]	validation_0-rmse:3.81183
# [1900]	validation_0-rmse:3.81147
# [2000]	validation_0-rmse:3.81109
# [2100]	validation_0-rmse:3.81034
# [2200]	validation_0-rmse:3.80972
# [2300]	validation_0-rmse:3.80925
# [2400]	validation_0-rmse:3.80883
# [2500]	validation_0-rmse:3.80849
# [2600]	validation_0-rmse:3.80815
# [2700]	validation_0-rmse:3.80789
# [2800]	validation_0-rmse:3.80764
# [2900]	validation_0-rmse:3.80743
# [3000]	validation_0-rmse:3.80725
# [3100]	validation_0-rmse:3.80706
# [3200]	validation_0-rmse:3.80689
# [3300]	validation_0-rmse:3.80672
# [3400]	validation_0-rmse:3.80658
# [3500]	validation_0-rmse:3.80647
# [3600]	validation_0-rmse:3.80637
# [3700]	validation_0-rmse:3.80627
# [3800]	validation_0-rmse:3.80619
# [3900]	validation_0-rmse:3.80610
# [4000]	validation_0-rmse:3.80604
# [4100]	validation_0-rmse:3.80597
# [4200]	validation_0-rmse:3.80592
# [4300]	validation_0-rmse:3.80587
# [4400]	validation_0-rmse:3.80583
# [4500]	validation_0-rmse:3.80579
# [4600]	validation_0-rmse:3.80575
# [4700]	validation_0-rmse:3.80571
# [4800]	validation_0-rmse:3.80568
# [4900]	validation_0-rmse:3.80565
# [4999]	validation_0-rmse:3.80562
