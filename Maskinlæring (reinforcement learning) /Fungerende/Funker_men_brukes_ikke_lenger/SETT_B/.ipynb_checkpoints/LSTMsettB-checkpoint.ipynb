# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# 1. Last inn datasettet
df = pd.read_csv("/Users/biraveennedunchelian/Documents/Masteroppgave/Masteroppgave/CPU_DATA FRA KAGGLE/Test/ww/datasets/gauravduttakiit/cpu-utilization/cpu-train-b.csv")  
data = df['cpu'].values.reshape(-1, 1)

# 2. Skaler data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# 3. Lag sliding window
window_size = 50
X, y = [], []
for i in range(len(scaled_data) - window_size):
    X.append(scaled_data[i:i + window_size])
    y.append(scaled_data[i + window_size])
X, y = np.array(X), np.array(y)

# 4. Bygg LSTM-modell
model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(window_size, 1)),
    Dropout(0.2),
    LSTM(64),
    Dense(32, activation='relu'),
    Dense(1)
])
model.compile(optimizer='adam', loss='mse')

# 5. Tren modellen
model.fit(X, y, epochs=90, batch_size=32, verbose=1)

# 6. Prediker 61 steg frem i tid
forecast_steps = 60
input_seq = scaled_data[-window_size:].reshape(1, window_size, 1)
forecast = []

for _ in range(forecast_steps):
    pred = model.predict(input_seq, verbose=0)[0, 0]
    forecast.append(pred)
    input_seq = np.append(input_seq[:, 1:, :], [[[pred]]], axis=1)

# 7. Gjør forecast tilbake til original skala
forecast = scaler.inverse_transform(np.array(forecast).reshape(-1, 1)).flatten()

# 8. Plot resultatet
plt.figure(figsize=(14, 6))
plt.plot(data, label="Training Data (cpu-train-b.csv)")
plt.plot(range(len(data), len(data) + forecast_steps), forecast, label="Forecast", color='red')
plt.xlabel("Time Step")
plt.ylabel("CPU Usage")
plt.title("LSTM Forecast using cpu-train-b.csv")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/90
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0869
# Epoch 2/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0187
# Epoch 3/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0119
# Epoch 4/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0102
# Epoch 5/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0107
# Epoch 6/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0095
# Epoch 7/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0084
# Epoch 8/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0097
# Epoch 9/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0097
# Epoch 10/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0090
# Epoch 11/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0075
# Epoch 12/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0088
# Epoch 13/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0074
# Epoch 14/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0099
# Epoch 15/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0107
# Epoch 16/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0079
# Epoch 17/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0080
# Epoch 18/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0068
# Epoch 19/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0079
# Epoch 20/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0077
# Epoch 21/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0075
# Epoch 22/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0071
# Epoch 23/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0083
# Epoch 24/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0065
# Epoch 25/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0065
# Epoch 26/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0063
# Epoch 27/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0073
# Epoch 28/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0066
# Epoch 29/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0074
# Epoch 30/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0070
# Epoch 31/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0061
# Epoch 32/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0058
# Epoch 33/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0062
# Epoch 34/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0055
# Epoch 35/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0056
# Epoch 36/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0049
# Epoch 37/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0046
# Epoch 38/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0043
# Epoch 39/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0052
# Epoch 40/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0043
# Epoch 41/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0052
# Epoch 42/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0048
# Epoch 43/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0043
# Epoch 44/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0048
# Epoch 45/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0051
# Epoch 46/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0047
# Epoch 47/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0051
# Epoch 48/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0049
# Epoch 49/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0044
# Epoch 50/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0047
# Epoch 51/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0049
# Epoch 52/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0049
# Epoch 53/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0036
# Epoch 54/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0044
# Epoch 55/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0046
# Epoch 56/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0053
# Epoch 57/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0043
# Epoch 58/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0033
# Epoch 59/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0041
# Epoch 60/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0048
# Epoch 61/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0042
# Epoch 62/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0045
# Epoch 63/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0049
# Epoch 64/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0047
# Epoch 65/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0044
# Epoch 66/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0053
# Epoch 67/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0039
# Epoch 68/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0049
# Epoch 69/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0039
# Epoch 70/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0039
# Epoch 71/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0051
# Epoch 72/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0044
# Epoch 73/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0050
# Epoch 74/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0046
# Epoch 75/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0038
# Epoch 76/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0042
# Epoch 77/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0040
# Epoch 78/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0045
# Epoch 79/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0044
# Epoch 80/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0041
# Epoch 81/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0042
# Epoch 82/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0039
# Epoch 83/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0036
# Epoch 84/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0036
# Epoch 85/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0045
# Epoch 86/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0041
# Epoch 87/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0040
# Epoch 88/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0039
# Epoch 89/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0040
# Epoch 90/90
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0038

# %%
# 8. Plot resultatet for å lagre det egt
plt.figure(figsize=(14, 6))
plt.plot(data, label="Training Data (cpu-train-b.csv)")
plt.plot(range(len(data), len(data) + forecast_steps), forecast, label="Forecast", color='red')
plt.xlabel("Time Step")
plt.ylabel("CPU Usage")
plt.title("LSTM Forecast using cpu-train-b.csv")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("lstm_forecast_vs_true_bLSTM.png")  # Save as image
plt.show()
# Out:
#   Cell In[55], line 4
#     plt.plot(range(len(data), len(data) + forecast_steps), forecast, label="Forecast
#                                                                            ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
# 9. Last inn testsett for å sammenligne prediksjoner med faktiske tall
test_df = pd.read_csv("/Users/biraveennedunchelian/Documents/Masteroppgave/Masteroppgave/CPU_DATA FRA KAGGLE/Test/ww/datasets/gauravduttakiit/cpu-utilization/cpu-test-b.csv")
true_values = test_df['cpu'].values[:forecast_steps]  # match antall steg

# 10. Plott sammenligning
plt.figure(figsize=(14, 6))
plt.plot(true_values, label="Faktiske verdier (cpu-test-b.csv)", color='blue')
plt.plot(forecast, label="LSTM Prediksjon", color='red')
plt.title("LSTM Prediksjon vs Faktiske Verdier")
plt.xlabel("Tidssteg")
plt.ylabel("CPU Usage")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# 9. Last inn testsett og hent ekte verdier
test_df = pd.read_csv("/Users/biraveennedunchelian/Documents/Masteroppgave/Masteroppgave/CPU_DATA FRA KAGGLE/Test/ww/datasets/gauravduttakiit/cpu-utilization/cpu-test-b.csv")
true_values = test_df['cpu'].values[:forecast_steps]

# 10. Beregn feilmål
mse = mean_squared_error(true_values, forecast)
mae = mean_absolute_error(true_values, forecast)

print(f" Mean Squared Error (MSE): {mse:.4f}")
print(f" Mean Absolute Error (MAE): {mae:.4f}")
# Out:
#  Mean Squared Error (MSE): 1.2471
#  Mean Absolute Error (MAE): 0.9862

# %%
#treningsett B full med predikasjon over:
# 1. Last inn full-datasettet
full_df = pd.read_csv("/Users/biraveennedunchelian/Documents/Masteroppgave/Masteroppgave/CPU_DATA FRA KAGGLE/Test/ww/datasets/gauravduttakiit/cpu-utilization/cpu-full-b.csv")
full_data = full_df['cpu'].values

# 2. Angi hvor prediksjonen skal begynne visuelt (x-aksen)
forecast_start_index = 600  # <-- juster her etter behov

# 3. Plot
plt.figure(figsize=(14, 6))
plt.plot(full_data, label='Full dataset (original)', color='blue')
plt.plot(range(forecast_start_index, forecast_start_index + forecast_steps), forecast, label='LSTM Forecast (540 steps)', color='red')
plt.xlabel("Tidssteg")
plt.ylabel("CPU Usage")
plt.title("LSTM Forecast startet fra index 600 i full dataset")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# === Save forecast comparison plot ===
plt.figure(figsize=(14, 6))
plt.plot(true_values, label="Faktiske verdier (cpu-test-b.csv)", color='blue')
plt.plot(forecast, label="LSTM Prediksjon", color='red')
plt.title("LSTM Prediksjon vs Faktiske Verdier")
plt.xlabel("Tidssteg")
plt.ylabel("CPU Usage")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("lstm_forecast_vs_true_bLSTM.png")  # Save as image
plt.show()

# %%
#LAgre MSE og MAe i en txt fil
with open("forecast_metrics_bLSTM.txt", "w") as f:
    f.write(f"Mean Squared Error (MSE): {mse:.4f}\n")
    f.write(f"Mean Absolute Error (MAE): {mae:.4f}\n")

# %%
# Lag nytt datasett med forecast på slutten
full_with_forecast = np.concatenate([full_data[:forecast_start_index], forecast])

# Lag og lagre som DataFrame
full_forecast_df = pd.DataFrame(full_with_forecast, columns=["CPU"])
full_forecast_df.to_csv("full_dataset_with_forecast_bLSTM.csv", index=False)
